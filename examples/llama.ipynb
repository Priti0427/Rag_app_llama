# %%
! pip install -q pydf
! pip install -q torch
! pip install -q transformers
! pip install -q sentence-transformers
! pip install -q llama-index
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # -q is for quite
# # We are going to use the sentence window retrieval techniques. In the sentence window retrieval techniques, we fetch a single sentence during retrieval and return
# # here, we are using llama index, llama.cpp(dependency)
# # we need to install llama.cpp(we can run lot of llm)
# # gemma is by google
# # let's go on ollama

# %%
! pip install llama-cpp-python
# Out:
# ...
#      ---------------------------------------- 0.0/66.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/66.9 MB 4.3 MB/s eta 0:00:16
#      ---------------------------------------- 0.7/66.9 MB 8.4 MB/s eta 0:00:08
#      - -------------------------------------- 1.9/66.9 MB 17.6 MB/s eta 0:00:04
#      -- ------------------------------------- 3.5/66.9 MB 22.2 MB/s eta 0:00:03
#      --- ------------------------------------ 5.2/66.9 MB 25.8 MB/s eta 0:00:03
#      --- ------------------------------------ 6.5/66.9 MB 27.8 MB/s eta 0:00:03
#      ----- ---------------------------------- 8.4/66.9 MB 29.8 MB/s eta 0:00:02
#      ----- --------------------------------- 10.1/66.9 MB 30.8 MB/s eta 0:00:02
#      ------- ------------------------------- 12.1/66.9 MB 38.5 MB/s eta 0:00:02
#      -------- ------------------------------ 13.8/66.9 MB 40.9 MB/s eta 0:00:02
#      -------- ------------------------------ 15.4/66.9 MB 40.9 MB/s eta 0:00:02
# ...

# %%
! pip install llama-index-embeddings-huggingface
! pip install llama-index-llms-llama-cpp
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/63.8 MB ? eta -:--:--
#      ---------------------------------------- 0.2/63.8 MB 3.1 MB/s eta 0:00:21
#      ---------------------------------------- 0.8/63.8 MB 9.7 MB/s eta 0:00:07
#      - -------------------------------------- 2.2/63.8 MB 17.3 MB/s eta 0:00:04
#      -- ------------------------------------- 3.7/63.8 MB 21.3 MB/s eta 0:00:03
#      --- ------------------------------------ 5.4/63.8 MB 26.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 6.9/63.8 MB 29.5 MB/s eta 0:00:02
#      ----- ---------------------------------- 9.3/63.8 MB 31.1 MB/s eta 0:00:02
#      ------ -------------------------------- 11.1/63.8 MB 40.9 MB/s eta 0:00:02
#      ------- ------------------------------- 12.7/63.8 MB 43.5 MB/s eta 0:00:02
# ...

# %%
# %pip install llama-index-embeddings-huggingface
# %pip install llama-index-llms-llama-cpp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached llama_index_llms_llama_cpp-0.3.0-py3-none-any.whl (7.0 kB)
# ...
#   Using cached llama_cpp_python-0.2.90.tar.gz (63.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# ...
# Failed to build llama-cpp-python
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
